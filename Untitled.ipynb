# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import ast

# %%
df = pd.read_json("Data/historical_data.json")

# %%
df
# Out:
#                                                 feeds  totalFeed
# 0   {'id': 2140, 'title': 'gj', 'description': 'gh...        125
# 1   {'id': 2139, 'title': 'dfg', 'description': 'd...        125
# 2   {'id': 2138, 'title': 'TEst Video', 'descripti...        125
# 3   {'id': 2137, 'title': 'QQ', 'description': 'qq...        125
# 4   {'id': 2136, 'title': 'gj', 'description': 'gh...        125
# ..                                                ...        ...
# 95  {'id': 53, 'title': 'new one', 'description': ...        125
# 96  {'id': 52, 'title': 'new one', 'description': ...        125
# 97  {'id': 51, 'title': 'ssfdfd', 'description': '...        125
# 98  {'id': 50, 'title': 'Test Code', 'description'...        125
# 99  {'id': 49, 'title': 'A mobile phone is a wirel...        125
#
# [100 rows x 2 columns]

# %%
df["feeds"][0].keys()
# Out:
# dict_keys(['id', 'title', 'description', 'location', 'lng', 'lat', 'userId', 'name', 'isdeleted', 'profilePicture', 'videoUrl', 'images', 'mediatype', 'imagePaths', 'feedsComment', 'commentCount', 'multiMedia', 'likeDislike', 'createdAt', 'code', 'msg'])

# %%
df["feeds"][0]
# Out:
# {'id': 2140,
#  'title': 'gj',
#  'description': 'ghj',
#  'location': 'Hermannplatz 5-6, 10967 Berlin, Germany',
#  'lng': 0,
#  'lat': 0,
#  'userId': 4051,
#  'name': 'manoj',
#  'isdeleted': False,
#  'profilePicture': 'Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png',
#  'videoUrl': None,
#  'images': None,
#  'mediatype': 0,
#  'imagePaths': None,
#  'feedsComment': None,
#  'commentCount': 0,
#  'multiMedia': [{'id': 3240,
#    'name': '',
#    'description': None,
#    'url': 'http://www.youtube.com/embed/mPhboJR0Llc',
#    'mediatype': 2,
#    'likeCount': 0,
#    'place': None,
#    'createAt': '0001-01-01T00:00:00'}],
#  'likeDislike': {'likes': 0, 'dislikes': 0, 'userAction': 2},
#  'createdAt': '2020-01-02T13:32:16.7480006',
#  'code': 0,
#  'msg': None}

# %%
df["feeds"][10]
# Out:
# {'id': 2130,
#  'title': 'dfg',
#  'description': 'dfgdf',
#  'location': 'Rannamõisa tee 4f, 13516 Tallinn, Estonia',
#  'lng': 0,
#  'lat': 0,
#  'userId': 3035,
#  'name': 'n1',
#  'isdeleted': False,
#  'profilePicture': 'Images/4e60754a-e8a7-4db7-b266-f28b2bcf00ae.png',
#  'videoUrl': None,
#  'images': None,
#  'mediatype': 0,
#  'imagePaths': None,
#  'feedsComment': None,
#  'commentCount': 1,
#  'multiMedia': [{'id': 3229,
#    'name': 'images.jpg',
#    'description': None,
#    'url': 'feedsmedia/3035/60ce92d1-b037-4a45-84a5-d6635095fa50.jpg',
#    'mediatype': 1,
#    'likeCount': 0,
#    'place': None,
#    'createAt': '0001-01-01T00:00:00'}],
#  'likeDislike': {'likes': 1, 'dislikes': 0, 'userAction': 2},
#  'createdAt': '2020-01-01T12:08:35.9430242',
#  'code': 0,
#  'msg': None}

# %%
cne = "select * from Data"
cne.split("from")[0].split("select")[1].strip()
# Out:
# '*'

# %%
with open('Data/historical_data.json') as json_data:
        data_dict = json.load(json_data)

data_str = json.dumps(data_dict)

# %%
# userId == 4051, to_select

# %%
list(data_dict['feeds'][0].keys())
# Out:
# ['id',
#  'title',
#  'description',
#  'location',
#  'lng',
#  'lat',
#  'userId',
#  'name',
#  'isdeleted',
#  'profilePicture',
#  'videoUrl',
#  'images',
#  'mediatype',
#  'imagePaths',
#  'feedsComment',
#  'commentCount',
#  'multiMedia',
#  'likeDislike',
#  'createdAt',
#  'code',
#  'msg']

# %%
data_dict['feeds'][0]
# Out:
# {'id': 2140,
#  'title': 'gj',
#  'description': 'ghj',
#  'location': 'Hermannplatz 5-6, 10967 Berlin, Germany',
#  'lng': 0,
#  'lat': 0,
#  'userId': 4051,
#  'name': 'manoj',
#  'isdeleted': False,
#  'profilePicture': 'Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png',
#  'videoUrl': None,
#  'images': None,
#  'mediatype': 0,
#  'imagePaths': None,
#  'feedsComment': None,
#  'commentCount': 0,
#  'multiMedia': [{'id': 3240,
#    'name': '',
#    'description': None,
#    'url': 'http://www.youtube.com/embed/mPhboJR0Llc',
#    'mediatype': 2,
#    'likeCount': 0,
#    'place': None,
#    'createAt': '0001-01-01T00:00:00'}],
#  'likeDislike': {'likes': 0, 'dislikes': 0, 'userAction': 2},
#  'createdAt': '2020-01-02T13:32:16.7480006',
#  'code': 0,
#  'msg': None}

# %%
for k,v in data_dict['feeds'][0].items():
    print(k, v)
# Out:
# id 2140
# title gj
# description ghj
# location Hermannplatz 5-6, 10967 Berlin, Germany
# lng 0
# lat 0
# userId 4051
# name manoj
# isdeleted False
# profilePicture Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png
# videoUrl None
# images None
# mediatype 0
# imagePaths None
# feedsComment None
# commentCount 0
# multiMedia [{'id': 3240, 'name': '', 'description': None, 'url': 'http://www.youtube.com/embed/mPhboJR0Llc', 'mediatype': 2, 'likeCount': 0, 'place': None, 'createAt': '0001-01-01T00:00:00'}]
# likeDislike {'likes': 0, 'dislikes': 0, 'userAction': 2}
# createdAt 2020-01-02T13:32:16.7480006
# code 0
# msg None

# %%
key_values = ["userId", 4051]
key = key_values[0]
typ = type(data_dict["feeds"][0][key])

# %%
typ
# Out:
# int

# %%
 data_dict['feeds'][0]
# Out:
# {'id': 2140,
#  'title': 'gj',
#  'description': 'ghj',
#  'location': 'Hermannplatz 5-6, 10967 Berlin, Germany',
#  'lng': 0,
#  'lat': 0,
#  'userId': 4051,
#  'name': 'manoj',
#  'isdeleted': False,
#  'profilePicture': 'Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png',
#  'videoUrl': None,
#  'images': None,
#  'mediatype': 0,
#  'imagePaths': None,
#  'feedsComment': None,
#  'commentCount': 0,
#  'multiMedia': [{'id': 3240,
#    'name': '',
#    'description': None,
#    'url': 'http://www.youtube.com/embed/mPhboJR0Llc',
#    'mediatype': 2,
#    'likeCount': 0,
#    'place': None,
#    'createAt': '0001-01-01T00:00:00'}],
#  'likeDislike': {'likes': 0, 'dislikes': 0, 'userAction': 2},
#  'createdAt': '2020-01-02T13:32:16.7480006',
#  'code': 0,
#  'msg': None}

# %%
{k:type(v) for k,v in data_dict['feeds'][0].items()}
# Out:
# {'id': int,
#  'title': str,
#  'description': str,
#  'location': str,
#  'lng': int,
#  'lat': int,
#  'userId': int,
#  'name': str,
#  'isdeleted': bool,
#  'profilePicture': str,
#  'videoUrl': NoneType,
#  'images': NoneType,
#  'mediatype': int,
#  'imagePaths': NoneType,
#  'feedsComment': NoneType,
#  'commentCount': int,
#  'multiMedia': list,
#  'likeDislike': dict,
#  'createdAt': str,
#  'code': int,
#  'msg': NoneType}

# %%
{k:type(v) for k,v in data_dict['feeds'][0]}
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# <ipython-input-39-7198f759ee71> in <module>
# ----> 1 {k:type(v) for k,v in data_dict['feeds'][0]}
#
# <ipython-input-39-7198f759ee71> in <dictcomp>(.0)
# ----> 1 {k:type(v) for k,v in data_dict['feeds'][0]}
#
# ValueError: too many values to unpack (expected 2)

# %%
[{k:v for k,v in x if k in to_select} for x in data_dict['feeds'] if x["userId"]==4051]
# Out:
# []

# %%
data_dict
# Out:
# '{"feeds": [{"id": 2140, "title": "gj", "description": "ghj", "location": "Hermannplatz 5-6, 10967 Berlin, Germany", "lng": 0, "lat": 0, "userId": 4051, "name": "manoj", "isdeleted": false, "profilePicture": "Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png", "videoUrl": null, "images": null, "mediatype": 0, "imagePaths": null, "feedsComment": null, "commentCount": 0, "multiMedia": [{"id": 3240, "name": "", "description": null, "url": "http://www.youtube.com/embed/mPhboJR0Llc", "mediatype": 2, "likeCount": 0, "place": null, "createAt": "0001-01-01T00:00:00"}], "likeDislike": {"likes": 0, "dislikes": 0, "userAction": 2}, "createdAt": "2020-01-02T13:32:16.7480006", "code": 0, "msg": null}, {"id": 2139, "title": "dfg", "description": "df", "location": "443 N Rodeo Dr, Beverly Hills, CA 90210, USA", "lng": 0, "lat": 0, "userId": 4051, "name": "manoj", "isdeleted": false, "profilePicture": "Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png", "videoUrl": null, "images": null, "mediatype": 0, 
# ...

# %%
data_dict['feeds'][0].values()
# Out:
# dict_values([2140, 'gj', 'ghj', 'Hermannplatz 5-6, 10967 Berlin, Germany', 0, 0, 4051, 'manoj', False, 'Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png', None, None, 0, None, None, 0, [{'id': 3240, 'name': '', 'description': None, 'url': 'http://www.youtube.com/embed/mPhboJR0Llc', 'mediatype': 2, 'likeCount': 0, 'place': None, 'createAt': '0001-01-01T00:00:00'}], {'likes': 0, 'dislikes': 0, 'userAction': 2}, '2020-01-02T13:32:16.7480006', 0, None])

# %%
import re

# %%
cne="insert into Data (colname1, colname2, val3) values (val1, val2, val3)"

# %%
columns_and_values = re.findall('\(.*?\)',cne)

columns_and_values
# Out:
# ["('id', 'title', 'description', 'location', 'lng', 'lat', 'userId', 'name', 'isdeleted', 'profilePicture', 'videoUrl', 'images', 'mediatype', 'imagePaths', 'feedsComment', 'commentCount', 'multiMedia', 'likeDislike', 'createdAt', 'code', 'msg')",
#  "(2140, 'gj', 'ghj', 'Hermannplatz 5-6, 10967 Berlin, Germany', 0, 0, 4051, 'manoj', False, 'Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png', None, None, 0, None, None, 0, [{'id': 3240, 'name': '', 'description': None, 'url': 'http://www.youtube.com/embed/mPhboJR0Llc', 'mediatype': 2, 'likeCount': 0, 'place': None, 'createAt': '0001-01-01T00:00:00'}], {'likes': 0, 'dislikes': 0, 'userAction': 2}, '2020-01-02T13:32:16.7480006', 0, None)"]

# %%
[x.lstrip("'").strip() for x in columns_and_values[1].lstrip("(").rstrip(")").split(",")]
# Out:
# ['2140',
#  "'gj'",
#  "'ghj'",
#  "'Hermannplatz 5-6",
#  '10967 Berlin',
#  "Germany'",
#  '0',
#  '0',
#  '4051',
#  "'manoj'",
#  'False',
#  "'Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png'",
#  'None',
#  'None',
#  '0',
#  'None',
#  'None',
#  '0',
#  "[{'id': 3240",
#  "'name': ''",
#  "'description': None",
#  "'url': 'http://www.youtube.com/embed/mPhboJR0Llc'",
#  "'mediatype': 2",
#  "'likeCount': 0",
#  "'place': None",
#  "'createAt': '0001-01-01T00:00:00'}]",
#  "{'likes': 0",
#  "'dislikes': 0",
#  "'userAction': 2}",
#  "'2020-01-02T13:32:16.7480006'",
#  '0',
#  'None']

# %%
columns_and_values[0].lstrip("(").rstrip(")").split(",")
# Out:
# ["'id'",
#  " 'title'",
#  " 'description'",
#  " 'location'",
#  " 'lng'",
#  " 'lat'",
#  " 'userId'",
#  " 'name'",
#  " 'isdeleted'",
#  " 'profilePicture'",
#  " 'videoUrl'",
#  " 'images'",
#  " 'mediatype'",
#  " 'imagePaths'",
#  " 'feedsComment'",
#  " 'commentCount'",
#  " 'multiMedia'",
#  " 'likeDislike'",
#  " 'createdAt'",
#  " 'code'",
#  " 'msg'"]

# %%
columns = columns_and_values[0].lstrip("(").rstrip(")").split(",")

values = columns_and_values[1].lstrip("(").rstrip(")").split(",")


to_insert = {k:v for k, v in zip(columns, values)}

to_insert
# Out:
# {'colname1': 'val1', ' colname2': ' val2', ' ...': ' '}

# %%
len(data_dict['feeds'])
# Out:
# 101

# %%
data_dict['feeds'].insert(len(data_dict['feeds']),  to_insert)

# %%
data_dict["feeds"].append(to_insert)

# %%
data_dict
# Out:
# {'feeds': [{'id': 2140,
#    'title': 'gj',
#    'description': 'ghj',
#    'location': 'Hermannplatz 5-6, 10967 Berlin, Germany',
#    'lng': 0,
#    'lat': 0,
#    'userId': 4051,
#    'name': 'manoj',
#    'isdeleted': False,
#    'profilePicture': 'Images/9b291404-bc2e-4806-88c5-08d29e65a5ad.png',
#    'videoUrl': None,
#    'images': None,
#    'mediatype': 0,
#    'imagePaths': None,
#    'feedsComment': None,
#    'commentCount': 0,
#    'multiMedia': [{'id': 3240,
#      'name': '',
#      'description': None,
#      'url': 'http://www.youtube.com/embed/mPhboJR0Llc',
#      'mediatype': 2,
#      'likeCount': 0,
#      'place': None,
#      'createAt': '0001-01-01T00:00:00'}],
#    'likeDislike': {'likes': 0, 'dislikes': 0, 'userAction': 2},
#    'createdAt': '2020-01-02T13:32:16.7480006',
#    'code': 0,
#    'msg': None},
#   {'id': 2139,
#    'title': 'dfg',
#    'description': 'df',
#    'location': '443 N Rodeo Dr, Beverly Hills, CA 90210, USA',
#    'lng': 0,
# ...
